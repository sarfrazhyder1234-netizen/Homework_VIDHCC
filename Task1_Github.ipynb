# %% [markdown]
# <a href="https://colab.research.google.com/github/sarfrazhyder1234-netizen/Homework_VIDHCC/blob/main/Task1_Github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
token = "My token************************************************* "
# Note: First i wanted to upload diretly but it gave warning to not share Token, so i just changed this manually

username = "sarfrazhyder1234-netizen"
repo = "Homework_VIDHCC"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'Homework_VIDHCC'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 1), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 6.53 KiB | 6.53 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd Homework_VIDHCC
# Out:
# /content/Homework_VIDHCC

# %%
with open("Task1.txt", "w") as f:
    f.write("Task 1 of Homework.\n")
    f.write("I created this file in Google Colab.\n")
    f.write("It is pushed in Repo!\n")

# %%
# !git config --global user.name "sarfrazhyder1234-netizen"
# !git config --global user.email "sarfrazhyder1234@gmail.com"

# %%
# !git add Task1.txt
# !git commit -m "Added Task_1.txt"
# Out:
# [main f4817a5] Added Task_1.txt
#  3 files changed, 1 insertion(+), 1 deletion(-)
#  delete mode 100644 HW.txt
#  delete mode 100644 myfirstfile.txt

# %%
# !git push
# Out:
# Everything up-to-date
